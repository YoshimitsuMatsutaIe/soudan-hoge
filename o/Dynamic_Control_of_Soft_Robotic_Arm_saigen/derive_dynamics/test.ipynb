# %%
import sympy as sy

import kinematics


l1, l2, l3 = sy.symbols("l1, l2, l3")
xi = sy.Symbol("xi")

q = sy.Matrix([[l1, l2, l3]]).T

hoge = kinematics.Base()
hoge.local_MHTM(q, xi)
# Out:
# Matrix([
# ...
